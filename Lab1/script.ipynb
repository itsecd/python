# %%
import requests
from bs4 import BeautifulSoup

# %%
url_rose = "https://yandex.ru/images/search?from=tabbar&text=rose.jpg"
html_rose = requests.get(url_rose)
print(html_rose.text)
# Out:
# <!DOCTYPE html><html class="i-ua_js_no i-ua_css_standard" lang="ru"><head><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><title>Яндекс Картинки</title><script nonce="7955641371817307842665">;(function(d,e,c,r){e=d.documentElement;c="className";r="replace";e[c]=e[c][r]("i-ua_js_no","i-ua_js_yes");if(d.compatMode!="CSS1Compat")e[c]=e[c][r]("i-ua_css_standart","i-ua_css_quirks")})(document);;(function(d,e,s,o,p){e=d.documentElement;s=e.style;o="object-fit";p="OObjectFit";e.className+=(o in s||p in s)?"":" i-ua_"+o+"_no"})(document);;(function(w,e,s,c,x,l,p,d){c="className";x="deviceXDPI";l="logicalXDPI";p="devicePixelRatio";d=x in s&&l in s&&s[x]/s[l]||p in w&&w[p];d>1&&(e[c]+=" i-ua_retina_yes")})(window,document.documentElement,screen);;document.documentElement.className+=" i-ua_orient_"+(window.innerWidth>window.innerHeight?"landscape":"portrait");;(function(d,e,c,n,w,v,f){e=d.documentElement;c="className";n="createElementNS";f="firstChild";w="http://www.w
# ...

# %%
soup_rose = BeautifulSoup(html_rose.text, 'lxml')
print(soup_rose.prettify())
# Out:
# <!DOCTYPE html>
# <html class="i-ua_js_no i-ua_css_standard" lang="ru">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Яндекс Картинки
#   </title>
#   <script nonce="7955641371817307842665">
# ...

# %%
r=soup_rose.find('img')
print(r)
# Out:
# <img class="cbir-intent__thumb"/>
